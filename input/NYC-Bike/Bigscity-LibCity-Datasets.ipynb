# %%
import pandas as pd

# %%
import os
cols = []
trips = []
path,dir,files =  next(iter(os.walk("./")))
col_set = set()   
columns = {
    "ride_id":"bikeid",
    "rideable_type":"usertype",
    "started_at":"starttime",
    "ended_at":"stoptime",
    "start_station_name":"start station name",
    "start_station_id":"start station id",
    "end_station_name":"end station name",
    "end_station_id":"end station id",
    "start_lat":"start station latitude",
    "start_lng":"start station longitude",
    "end_lat":"end station latitude",
    "end_lng":"end station longitude",
    "member_casual":"gender",
    
} 
for file in sorted(files):
    if file.endswith(".csv"):
        print(file)
        trip = pd.read_csv(file)
        col = trip.columns
        cols.append(col)
        col = ", ".join(list(col))
        print(col)
        print("*"*10)
        col_set.add(col)
        if len(col_set) > 1:
            trip.rename(columns=columns,inplace=True)
            trip.to_csv(file)
# Out:
# 201901-citibike-tripdata.csv
# tripduration, starttime, stoptime, start station id, start station name, start station latitude, start station longitude, end station id, end station name, end station latitude, end station longitude, bikeid, usertype, birth year, gender
# **********
# 201902-citibike-tripdata.csv
# tripduration, starttime, stoptime, start station id, start station name, start station latitude, start station longitude, end station id, end station name, end station latitude, end station longitude, bikeid, usertype, birth year, gender
# **********
# 201903-citibike-tripdata.csv
# tripduration, starttime, stoptime, start station id, start station name, start station latitude, start station longitude, end station id, end station name, end station latitude, end station longitude, bikeid, usertype, birth year, gender
# **********
# 201904-citibike-tripdata.csv
# ...

# %%
trip = pd.read_csv("202103-citibike-tripdata.csv")
col = trip.columns
print(col)
col_str = ", ".join(list(col))
col_str
# Out:
# /home/ubuntu/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3185: DtypeWarning: Columns (6,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# Index(['Unnamed: 0', 'bikeid', 'usertype', 'starttime', 'stoptime',
#        'start station name', 'start station id', 'end station name',
#        'end station id', 'start station latitude', 'start station longitude',
#        'end station latitude', 'end station longitude', 'gender'],
#       dtype='object')
# 'Unnamed: 0, bikeid, usertype, starttime, stoptime, start station name, start station id, end station name, end station id, start station latitude, start station longitude, end station latitude, end station longitude, gender'

# %%
trip = pd.read_csv("202101-citibike-tripdata.csv")
col = trip.columns
print(len(list(col)))
col_str_2 = ", ".join(list(col))
col_str_2
# Out:
# 15
# 'tripduration, starttime, stoptime, start station id, start station name, start station latitude, start station longitude, end station id, end station name, end station latitude, end station longitude, bikeid, usertype, birth year, gender'

# %%
trip = pd.read_csv("202103-citibike-tripdata.csv")
col = trip.columns
'ride_id, rideable_type, started_at, ended_at,
start_station_name, start_station_id,
end_station_name, end_station_id,
start_lat, start_lng, end_lat, end_lng,
member_casual'
print(len(list(col)))
col_str_3 = ", ".join(list(col))
col_str_3
columns = {
    "ride_id":"bikeid",
    "rideable_type":"usertype",
    "started_at":"starttime",
    "ended_at":"stoptime",
    "start_station_name":"start station name",
    "start_station_id":"start station id",
    "end_station_name":"end station name",
    "end_station_id":"end station id",
    "start_lat":"start station latitude",
    "start_lng":"start station longitude",
    "end_lat":"end station latitude",
    "end_lng":"end station longitude",
    "member_casual":"gender",
    
}
# Out:
#   File "/tmp/ipykernel_13167/2140303530.py", line 3
#     'ride_id, rideable_type, started_at, ended_at,
#                                                   ^
# SyntaxError: EOL while scanning string literal
